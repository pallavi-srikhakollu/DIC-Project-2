# %%
import requests
import codecs
import csv
from bs4 import BeautifulSoup 
import json
import io
import gzip
from html.parser import HTMLParser

# %%
get_requests1 = requests.get('http://index.commoncrawl.org/CC-MAIN-2019-09-index?url=http%3A%2F%2Fhttps://www.sbnation.com/&output=json')
get_requests2 = requests.get('http://index.commoncrawl.org/CC-MAIN-2019-04-index?url=http%3A%2F%2Fhttps://www.sbnation.com/&output=json')
requestsArray = []
requestsArray.append(get_requests1)
requestsArray.append(get_requests2)

# %%
pageList = []
for r in requestsArray:
    if r.status_code == 200:
        pages = r.content.splitlines()
        for i in pages:
            pageList.append(json.loads(i))

print(pages)
#pages = [json.loads(x) for x in get_requests.content.decode('utf8').strip().split('\n')]
#page = pages[2]
# Out:
# [b'{"urlkey": "com,sbnation)/", "timestamp": "20190116013323", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "11766709", "length": "591", "url": "http://www.sbnation.com/", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583656577.40/crawldiagnostics/CC-MAIN-20190116011131-20190116033131-00510.warc.gz", "mime": "unk", "status": "301", "mime-detected": "application/octet-stream"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190116013324", "digest": "CWLUVPOAYT3ZJQNUYOPCW7NUIQJF2K5A", "offset": "926742490", "length": "89840", "url": "https://www.sbnation.com/", "languages": "eng", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583656577.40/warc/CC-MAIN-20190116011131-20190116033131-00255.warc.gz", "mime": "text/html", "charset": "UTF-8", "status": "200", "mime-detected": "text/html"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190116165539", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "2121313", "length": "591", "url": "http://www.sbnation.com", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583657555.87/robotstxt/CC-MAIN-20190116154927-20190116180927-00465.warc.gz", "mime": "unk", "status": "301", "mime-detected": "application/octet-stream"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190116165539", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "11423730", "length": "592", "url": "http://www.sbnation.com/", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583657555.87/crawldiagnostics/CC-MAIN-20190116154927-20190116180927-00510.warc.gz", "mime": "unk", "status": "301", "mime-detected": "application/octet-stream"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190116165539", "digest": "5P7MNE54SKHEFSKWP3QD42Z2ZVH4N57W", "offset": "925523495", "length": "75809", "url": "https://www.sbnation.com/", "languages": "eng", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583657555.87/warc/CC-MAIN-20190116154927-20190116180927-00255.warc.gz", "mime": "text/html", "charset": "UTF-8", "status": "200", "mime-detected": "text/html"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190117011129", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "1799917", "length": "593", "url": "http://www.sbnation.com", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583658662.31/robotstxt/CC-MAIN-20190117000104-20190117022104-00465.warc.gz", "mime": "unk", "status": "301", "mime-detected": "application/octet-stream"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190117011129", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "10476008", "length": "591", "url": "http://www.sbnation.com/", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583658662.31/crawldiagnostics/CC-MAIN-20190117000104-20190117022104-00510.warc.gz", "mime": "unk", "status": "301", "mime-detected": "application/octet-stream"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190117011129", "digest": "6RKVWSKQGO42W24ELBCQNXNP2XQNBISY", "offset": "949474479", "length": "72456", "url": "https://www.sbnation.com/", "languages": "eng", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583658662.31/warc/CC-MAIN-20190117000104-20190117022104-00255.warc.gz", "mime": "text/html", "charset": "UTF-8", "status": "200", "mime-detected": "text/html"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190117210951", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "1819211", "length": "590", "url": "http://www.sbnation.com", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583659340.1/robotstxt/CC-MAIN-20190117204652-20190117230652-00465.warc.gz", "mime": "unk", "status": "301", "mime-detected": "application/octet-stream"}', b'{"urlkey": "com,sbnation)/", "timestamp": "20190117210951", "digest": "3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ", "offset": "10318924", "length": "592", "url": "http://www.sbnation.com/", "filename": "crawl-data/CC-MAIN-2019-04/segments/1547583659340.1/crawldiagnostics/CC-MAIN-20190117204652-20190117230652-00510.warc.gz", "mime": "unk", "status": "301", "mime-detected": "applicat ...

# %%
page = pageList[1]
print(page)
# Out:
# {'urlkey': 'com,sbnation)/', 'timestamp': '20190215195138', 'digest': 'MGZQJN3RQKQGNCJELBCOEEXHANDCTVVI', 'offset': '968773529', 'length': '88932', 'url': 'https://www.sbnation.com/', 'languages': 'eng', 'filename': 'crawl-data/CC-MAIN-2019-09/segments/1550247479101.30/warc/CC-MAIN-20190215183319-20190215205319-00255.warc.gz', 'mime': 'text/html', 'charset': 'UTF-8', 'status': '200', 'mime-detected': 'text/html'}

# %%
offset, length = int(page['offset']), int(page['length'])
offset_end = offset + length - 1
print(offset, length, offset_end)

#prefix = 'https://aws-publicdatasets.s3.amazonaws.com/'
prefix = 'https://commoncrawl.s3.amazonaws.com/'

response = requests.get(prefix + page['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
#response = requests.get("https://commoncrawl.s3.amazonaws.com/crawl-data/CC-MAIN-2019-09/segments/1550247479627.17/wet/CC-MAIN-20190215224408-20190216010408-00271.warc.wet.gz", headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
print(response)
# Out:
# 968773529 88932 968862460
# <Response [206]>

# %%
raw_data = io.BytesIO(response.content)
print(raw_data)
f = gzip.GzipFile(fileobj=raw_data)
print(f)
# Out:
# <_io.BytesIO object at 0x1152f9e60>
# <gzip _io.BytesIO object at 0x1152f9e60 0x1128f0cf8>

# %%
data = f.read()
#print(data)
#resp = ""
#if len(data):
#    try:
#        resp = data.decode('utf8').strip().split('\r\n\r\n', 2)
#    except:
#        pass
#print(resp)

# %%
#doc = parse(io.BytesIO(data)).getroot()
doc = BeautifulSoup(io.BytesIO(data), 'lxml')
#print(doc)
all_a = doc.find_all('a')
hrefList = []
if all_a:
    for l in all_a:
        #print(l)
        href = l.attrs.get('href')
        
        if href is not None:
            if href.startswith('http'):
                hrefList.append(href)

# %%
with codecs.open('links.csv', 'wb', encoding = 'utf8') as output:
    f = ['url']
    write_csv = csv.DictWriter(output, fieldnames = f)
    write_csv.writeheader()
    
    for h in hrefList:
        write_csv.writerow({'url':h})
        
hrefList = list( dict.fromkeys(hrefList) )

for h in hrefList:
    print(h)
# Out:
# http://www.sportingnews.com/us
# http://www.sportingnews.com/us/nfl/scoreboard
# http://www.sportingnews.com/us/nfl
# http://www.sportingnews.com/us/nba
# http://www.sportingnews.com/us/mlb
# http://www.sportingnews.com/us/nhl
# http://www.sportingnews.com/us/boxing
# http://www.sportingnews.com/us/ncaa-football
# http://www.sportingnews.com/us/ncaa-basketball
# http://www.sportingnews.com/us/mma
# http://bit.ly/2NYRJKC
# http://www.sportingnews.com/us/fantasy
# http://www.sportingnews.com/us/nascar
# http://www.sportingnews.com/us/soccer
# http://www.sportingnews.com/us/tennis
# http://www.sportingnews.com/us/athletics
# http://www.sportingnews.com/us/golf
# http://www.sportingnews.com/us/wwe
# http://www.sportingnews.com/us/other-sports
# https://www.facebook.com/sportingnews
# https://www.twitter.com/sportingnews
# https://instagram.com/sportingnews/
# http://www.goal.com
# http://www.sportingnews.com/us/writers
# http://www.sportingnews.com/us/newsletter/signup
# http://shop.sportingnews.com
# http://www.sportingnews.com/us/privacy
# http://www.sportingnews.com/us/customer-service/contact
# http://www.sportingnews.com/us/nfl/videos
# http://www.sportingnews.com/us/nfl/photos
# http://www.sportingnews.com/us/nfl/lists
# http://www.sportingnews.com/us/nfl/schedule
# http://www.sportingnews.com/us/nfl/standings
# http://www.sportingnews.com/us/nfl/draft/2018/draft-results/round/1
# http://www.sportingnews.com/us/nfl/news
# http://shop.sportingnews.com/NFL
# http://www.sportingnews.com/us/nba/news/nba-draft-2018-picks-order-results-first-second-round-1-2-full-list-players/597abh4mxruw10wln80n5xa94
# http://www.sportingnews.com/us/nba/videos
# http://www.sportingnews.com/us/nba/photos
# http://www.sportingnews.com/us/nba/lists
# http://www.sportingnews.com/us/nba/scoreboard
# http://www.sportingnews.com/us/nba/schedule
# http://www.sportingnews.com/us/nba/standings
# http://shop.sportingnews.com/NBA
# http://www.sportingnews.com/us/mlb/videos
# http://www.sportingnews.com/us/mlb/photos
# http://www.sportingnews.com/us/mlb/lists
# http://www.sportingnews.com/us/mlb/scoreboard
# http://www.sportingnews.com/us/mlb/schedule
# http://www.sportingnews.com/us/mlb/standings
# http://www.sportingnews.com/us/mlb/news
# http://shop.sportingnews.com/MLB
# http://www.sportingnews.com/us/nhl/videos
# http://www.sportingnews.com/us/nhl/photos
# http://www.sportingnews.com/us/nhl/lists
# http://www.sportingnews.com/us/nhl/scoreboard
# http://www.sportingnews.com/us/nhl/schedule
# http://www.sportingnews.com/us/nhl/standings
# http://www.sportingnews.com/us/nhl/news
# http://shop.sportingnews.com/NHL
# https://www.sportingnews.com/us/boxing/canelo-alvarez
# http://www.sportingnews.com/us/boxing/videos
# http://www.sportingnews.com/us/ncaa-football/videos
# http://www.sportingnews.com/us/ncaa-football/photos
# http://www.sportingnews.com/us/ncaa-football/lists
# http://www.sportingnews.com/us/ncaa-football/scoreboard
# http://www.sportingnews.com/us/ncaa-football/schedule
# http://www.sportingnews.com/us/ncaa-football/standings
# http://www.sportingnews.com/us/ncaa-football/polls
# http://www.sportingnews.com/us/ncaa-football/news
# http://shop.sportingnews.com/COLLEGE
# http://www.sportingnews.com/us/ncaa-basketball/tournament/2018/bracket
# http://www.sportingnews.com/us/ncaa-basketball/videos
# http://www.sportingnews.com/us/ncaa-basketball/photos
# http://www.sportingnews.com/us/ncaa-basketball/lists
# http://www.sportingnews.com/us/ncaa-basketball/scoreboard
# http://www.sportingnews.com/us/ncaa-basketball/schedule
# http://www.sportingnews.com/us/ncaa-basketball/standings
# http://www.sportingnews.com/us/ncaa-basketball/polls
# http://www.sportingnews.com/us/ncaa-basketball/news
# http://www.sportingnews.com/us/mma/photos
# http://www.sportingnews.com/us/mma/lists
# http://www.sportingnews.com/us/mma/videos
# http://www.sportingnews.com/us/mma/news
# http://www.sportingnews.com/us/fantasy/player-updates
# http://www.sportingnews.com/us/fantasy/tag/rankings
# http://www.sportingnews.com/us/fantasy/tag/dfs
# http://www.rotoql.com/sportingnews/
# http://www.sportingnews.com/us/fantasy/news
# http://www.sportingnews.com/us/author/16-reid-spencer
# http://www.sportingnews.com/us/author/402-jackie-spiegel
# http://www.sportingnews.com/us/author/279-thomas-lott
# http://www.sportingnews.com/us/author/404-mark-lelinwalla
# http://www.sportingnews.com/ca/wwe/news/the-five-greatest-road-to-wrestlemania-moments-in-wwe-history/1hgrrhoz8kf0a1ed38ycjsxbgu
# http://www.sportingnews.com/ca/soccer/news/you-cant-do-that---neuer-annoyed-with-bayern-munichs-defensive-madness/174ma9nf5k20a11a87cte9ebep
# http://www.sportingnews.com/ca/soccer/news/wolves-duo-coady-and-doherty-sign-contract-extensions/89x5o0lywy3b1bcgwl7v11vnu
# http://www.sportingnews.com/ca/soccer/news/wilson-determined-to-be-a-liverpool-player-having-made-his-allegiances-clear-at-old-trafford/1fi7iuzlge5gz1xxvu1e46cjrw
# http://www.sportingnews.com/us/
# http://www.sportingnews.com/us/author/398-alexis-mansanarez
# http://www.sportingnews.com/us/author/27-david-steele
# http://www.sportingnews.com/us/author/6-sean--deveney
# http://www.sportingnews.com/us/author/356-chelsea-howard
# http://www.sportingnews.com/us/author/406-dan-bernstein
# http://www.sportingnews.com/us/?page=2
# http://www.performgroup.com/brands/sporting-news/
# http://www.performgroup.co.uk/
# http://shop.sportingnews.com/
# http://twitter.com/sportingnews

# %%
#hrefList[1]
all_text = ""
for h in hrefList:
     print("---------------")
     print(h)
     response = requests.get(h)
     if response.status_code == 200:
         doc = BeautifulSoup(response.text, 'html.parser')
         name_box = doc.find_all('p')

         for name in name_box:
            for x in name.find_all('a'):
                x.replaceWithChildren()

         for link in name_box:
            all_text+=link.text
     #print("----------------------------------------------------")
     #print(all_text)

print(all_text)
    
#p = requests.get(hrefList[1])
#print(p.status_code)
#print(p.text)
'''pageListFinal = []
if p.status_code == 200:
    pagesFinal = p.content
    print(pagesFinal)
    for i in pagesFinal:
        pageListFinal.append(json.loads(i))'''
        
#print(pageListFinal[0])
# Out:
# ---------------
# http://www.sbnation.com
# ---------------
# https://auth.voxmedia.com/login?return_to=https%3A%2F%2Fwww.sbnation.com%2F
# ---------------
# https://auth.voxmedia.com/login?return_to=https%3A%2F%2Fwww.sbnation.com%2F
# ---------------
# https://auth.voxmedia.com/signup?return_to=https%3A%2F%2Fwww.sbnation.com%2F
# ---------------
# http://www.sbnation.com/videos
# ---------------
# http://www.sbnation.com/nfl
# ---------------
# http://www.sbnation.com/nba
# ---------------
# http://www.sbnation.com/wnba
# ---------------
# http://www.sbnation.com/mlb
# ---------------
# http://www.sbnation.com/college-football
# ---------------
# http://www.sbnation.com/soccer
# ---------------
# http://www.mmafighting.com/
# ---------------
# http://www.sbnation.com/golf
# ---------------
# http://www.sbnation.com/nhl
# ---------------
# http://www.sbnation.com/college-basketball
# ---------------
# https://store.sbnation.com/
# ---------------
# http://www.sbnation.com/college-football-recruiting
# ---------------
# http://www.sbnationradio.com
# ---------------
# http://www.sbnation.com/nascar
# ---------------
# http://www.sbnation.com/fantasy
# ---------------
# http://www.sbnation.com/tennis
# ---------------
# http://www.podiumcafe.com/
# ---------------
# http://www.badlefthook.com/
# ---------------
# http://www.sbnation.com/podcasts
# ---------------
# http://www.cagesideseats.com/
# ---------------
# http://www.outsports.com/
# ---------------
# https://www.sbnation.com/sports-betting-odds-gambling
# ---------------
# https://www.stubhub.com/sports-tickets/category/28/?gcid=chAFF-_-geoUS-_-genAllTix-_-dt160923-_-cmpSBNation_NavBar-_-partVOX
# ---------------
# http://www.sbnation.com/videos
# ---------------
# http://www.sbnation.com/nfl
# ---------------
# http://www.sbnation.com/fantasy
# ---------------
# http://www.revengeofthebirds.com/
# ---------------
# http://www.thefalcoholic.com/
# ---------------
# http://www.baltimorebeatdown.com/
# ---------------
# http://www.buffalorumblings.com/
# ---------------
# http://www.catscratchreader.com/
# ---------------
# http://www.windycitygridiron.com/
# ---------------
# http://www.cincyjungle.com/
# ---------------
# http://www.dawgsbynature.com/
# ---------------
# http://www.bloggingtheboys.com/
# ---------------
# http://www.milehighreport.com/
# ---------------
# http://www.prideofdetroit.com/
# ---------------
# http://www.acmepackingcompany.com/
# ---------------
# http://www.battleredblog.com/
# ---------------
# http://www.stampedeblue.com/
# ---------------
# http://www.bigcatcountry.com/
# ---------------
# http://www.arrowheadpride.com/
# ---------------
# http://www.turfshowtimes.com/
# ---------------
# http://www.thephinsider.com/
# ---------------
# http://www.dailynorseman.com/
# ---------------
# http://www.patspulpit.com/
# ---------------
# http://www.canalstreetchronicles.com/
# ---------------
# http://www.bigblueview.com/
# ---------------
# http://www.ganggreennation.com/
# ---------------
# http://www.silverandblackpride.com/
# ---------------
# http://www.bleedinggreennation.com/
# ---------------
# http://www.behindthesteelcurtain.com/
# ---------------
# http://www.boltsfromtheblue.com/
# ---------------
# http://www.ninersnation.com/
# ---------------
# http://www.fieldgulls.com/
# ---------------
# http://www.bucsnation.com/
# ---------------
# http://www.musiccitymiracles.com/
# ---------------
# http://www.hogshaven.com/
# ---------------
# http://www.sbnation.com/nfl-mock-draft
# ---------------
# http://www.sbnation.com/nfl/odds
# ---------------
# http://www.sbnation.com/nba
# ---------------
# http://www.sbnation.com/wnba
# ---------------
# http://www.peachtreehoops.com/
# ---------------
# http://www.celticsblog.com/
# ---------------
# http://www.netsdaily.com/
# ---------------
# http://www.atthehive.com/
# ---------------
# http://www.blogabull.com/
# ---------------
# http://www.fearthesword.com/
# ---------------
# http://www.mavsmoneyball.com/
# ---------------
# http://www.denverstiffs.com/
# ---------------
# http://www.detroitbadboys.com/
# ---------------
# http://www.goldenstateofmind.com/
# ---------------
# http://www.thedreamshake.com/
# ---------------
# http://www.indycornrows.com/
# ---------------
# http://www.clipsnation.com/
# ---------------
# http://www.silverscreenandroll.com/
# ---------------
# http://www.grizzlybearblues.com/
# ---------------
# http://www.hothothoops.com/
# ---------------
# http://www.brewhoop.com/
# ---------------
# http://www.canishoopus.com/
# ---------------
# http://www.thebirdwrites.com/
# ---------------
# http://www.postingandtoasting.com/
# ---------------
# http://www.welcometoloudcity.com/
# ---------------
# http://www.orlandopinstripedpost.com/
# ---------------
# http://www.libertyballers.com/
# ---------------
# http://www.brightsideofthesun.com/
# ---------------
# http://www.blazersedge.com/
# ---------------
# http://www.sactownroyalty.com/
# ---------------
# http://www.poundingtherock.com/
# ---------------
# http://www.sonicsrising.com/
# ---------------
# http://www.raptorshq.com/
# ---------------
# http://www.slcdunk.com/
# ---------------
# http://www.bulletsforever.com/
# ---------------
# https://www.sbnation.com/nba-2k
# ---------------
# http://www.ridiculousupside.com/
# ---------------
# http://www.sbnation.com/nba/odds
# ---------------
# http://www.swishappeal.com
# ---------------
# http://www.sbnation.com/wnba
# ---------------
# http://www.sbnation.com/mlb
# ---------------
# http://www.azsnakepit.com/
# ---------------
# http://www.talkingchop.com/
# ---------------
# http://www.camdenchat.com/
# ---------------
# http://www.overthemonster.com/
# ---------------
# http://www.bleedcubbieblue.com/
# ---------------
# http://www.southsidesox.com/
# ---------------
# http://www.redreporter.com/
# ---------------
# http://www.letsgotribe.com/
# ---------------
# http://www.purplerow.com/
# ---------------
# http://www.blessyouboys.com/
# ---------------
# http://www.crawfishboxes.com/
# ---------------
# http://www.royalsreview.com/
# ---------------
# http://www.halosheaven.com/
# ---------------
# http://www.truebluela.com/
# ---------------
# http://www.fishstripes.com/
# ---------------
# http://www.brewcrewball.com/
# ---------------
# http://www.twinkietown.com/
# ---------------
# http://www.amazinavenue.com/
# ---------------
# http://www.pinstripealley.com/
# ---------------
# http://www.athleticsnation.com/
# ---------------
# http://www.thegoodphight.com/
# ---------------
# http://www.bucsdugout.com/
# ---------------
# http://www.gaslampball.com/
# ---------------
# http://www.mccoveychronicles.com/
# ---------------
# http://www.lookoutlanding.com/
# ---------------
# http://www.vivaelbirdos.com/
# ---------------
# http://www.draysbay.com/
# ---------------
# http://www.lonestarball.com/
# ---------------
# http://www.bluebirdbanter.com/
# ---------------
# http://www.federalbaseball.com/
# ---------------
# http://www.faketeams.com/
# ---------------
# http://www.sbnation.com/mlb/odds
# ---------------
# http://www.mlbdailydish.com/
# ---------------
# http://www.minorleagueball.com/
# ---------------
# http://www.beyondtheboxscore.com/
# ---------------
# http://www.sbnation.com/college-football
# ---------------
# http://www.footballstudyhall.com/
# ---------------
# http://www.sbnation.com/college-football/odds
# ---------------
# http://www.sbnation.com/college-football-recruiting
# ---------------
# http://www.everydayshouldbesaturday.com/
# ---------------
# http://www.sbnation.com/blogs#college
# ---------------
# http://www.sbnation.com/soccer
# ---------------
# http://www.sbnation.com/bundesliga
# ---------------
# http://www.sbnation.com/epl
# ---------------
# http://www.sbnation.com/serie-a
# ---------------
# http://www.sbnation.com/mls
# ---------------
# http://www.sbnation.com/nwsl-womens-soccer
# ---------------
# http://soccer.oddsshark.com
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# ~/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x1170d12b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='soccer.oddsshark.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1170d12b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-5436242e0a2b> in <module>()
#       4      print("---------------")
#       5      print(h)
# ----> 6      response = requests.get(h)
#       7      if response.status_code == 200:
#       8          doc = BeautifulSoup(response.text, 'html.parser')
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='soccer.oddsshark.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1170d12b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
print(response.status_code)
# Out:
# 200

# %%
#print(all_text)
text_file = open("Common_crawl_sbnation_com_text_11_Apr.txt", "w")
text_file.write( all_text)
text_file.close()

# %%
 response = requests.get("http://shop.sportingnews.com/COLLEGE")
 doc = BeautifulSoup(response.text, 'html.parser')
 #print(doc)
    
 name_box = doc.find_all('p')
 all_text = ""
 for name in name_box:
    #print(".................")
    #print(name)
    
    for x in name.find_all('a'):
        x.replaceWithChildren()
        #all_text += (x.get_text()) 
        #print(all_text)
    #print("%%%%%%%%%%%")
    #print(name)
    #all_text += name
    #print(all_text)

for link in name_box:
    all_text+=link.text
print(all_text)
# Out:
# The Villanova Wildcats reigned supreme in March Madness, so gear up for the champs with our wide range of NCAA Basketball Apparel including official Villanova National Champs Gear that allow Wildcats fans to ring in their second title in three years! Score more than just College Basketball Gear at Fanatics, as we're always to stock your closet with NCAA Football Apparel and College Baseball Gear. Fanatics.com is your ultimate College Apparel store, bringing Students, Fans and Alumni all the College Gear they could ever need. With a huge selection of College Jerseys, College Clothing, NCAA Sweatshirts and T-Shirts, every die-hard fan or alumnus can find a way to show their school pride. We offer College Sportswear for over 500 schools, so you can be sure you're checking out the largest collection of officially licensed College Gear and NCAA Merchandise anywhere. Our NCAA Shop houses an endless variety of College Jerseys so you'll be totally set for every season.
#
#                   Shop: College Polo Shirts | College Jerseys | NCAA Baseball Hats For the very best in authentic College Clothing, check out our NCAA Shop. With everything from gifts and collectibles to championship gear, our NCAA Shop has got all your College gear needs covered. Our selection of NCAA Merchandise is all officially licensed, so you can be sure you're sporting the most authentic team gear. Our NCAA Store has everything for your next game day, including NCAA Football Gear, Clothing and any type of NCAA gear or accessories a fan could dream of. Shop for NCAA Clothing and tailgating items here and your fellow fans are sure to be impressed. With retro looks, vintage gear and the latest styles from your team, you have a wide variety of officially licensed NCAA Clothing to choose from. Enjoy the NCAA Fan Shop and browse for all your NCAA shopping needs. You can find something for every person on your shopping list in this massive collection of authentic NCAA Gear!Get the appsFollow UsSecure ShoppingPayment Options©2019 Fanatics, Inc., All Rights Reserved. No portion of this site may be reproduced or duplicated without the express permission of Fanatics, Inc.

# %%
import nltk
sno = nltk.stem.SnowballStemmer('english')
sno.stem('grows')
'grow'
sno.stem('leaves')
'leav'
sno.stem('fairly')
'fair'
# Out:
# 'fair'

# %%
import nltk
sno = nltk.stem.SnowballStemmer('english')
words
