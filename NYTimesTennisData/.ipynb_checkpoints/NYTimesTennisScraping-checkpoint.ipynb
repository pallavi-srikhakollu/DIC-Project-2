# %%
import requests
from bs4 import BeautifulSoup
import re
from collections import defaultdict
from collections import Counter
import nltk
#sno = nltk.stem.SnowballStemmer('english')
sno = nltk.wordnet.WordNetLemmatizer()

# %%
import pandas as pd
df = pd.read_csv("ny_tennis_18Apr1.csv")
url_list = df['url']

# %%
all_text = ""
filename = "ny_tennis_"
file_counter = 0
for urli in url_list:
    
    if "tennis" not in urli and "australian-open" not in urli:
        continue
    print(urli)
    all_text = ""
    
    response = requests.get(urli)
    doc = BeautifulSoup(response.text, 'html.parser')
    links = doc.find_all('p')
    
    for name in links:
            for x in name.find_all('a'):
                x.replaceWithChildren()
                
    for link in links:
        link_text = link.text
   
        link_text = re.sub('\ by', '', link_text)
        link_text = re.sub('Advertisement  ', '', link_text)
        link_text = re.sub('Supported', '', link_text)
        link_text = re.sub('Advertisement$', '', link_text)
        
        filtered_text = re.sub('[0-9]+', ',', link_text)
        filtered_text = re.sub(r'[^\w\s]',' ',filtered_text)
        filtered_text = filtered_text.lower()

        inv_indx = defaultdict(list)

        words = (filtered_text.split())
        for word in words:
            inv_indx[word].append(1)
            
        for word in inv_indx:
            #stem_word = sno.stem(word)
            stem_word = sno.lemmatize(word)
            if stem_word != word:
                filtered_text = filtered_text.replace(word,stem_word)
                
        all_text += filtered_text
        all_text+=" <BRK> "
    
    
    if all_text == "":
        continue
        
    file_counter += 1    
    curr_file_name = filename + str(file_counter) + ".txt"
    text_file = open(curr_file_name, "w")
    text_file.write( all_text)
    text_file.close()
    print("New file writing",file_counter)

#print(all_text)
# Out:
# https://www.nytimes.com/2019/01/20/sports/australian-open-lleyton-hewitt-tomic-turmoil.html
# New file writing 1
# https://www.nytimes.com/2019/01/12/sports/tennis/how-are-ties-broken-in-tennis-that-depends.html
# New file writing 2
# https://www.nytimes.com/reuters/2019/04/05/sports/tennis/05reuters-tennis-charleston.html
# New file writing 3
# https://www.nytimes.com/reuters/2019/04/12/sports/tennis/12reuters-tennis-houston.html
# New file writing 4
# https://www.nytimes.com/2019/01/09/sports/australian-open-rebecca-marino.html
# New file writing 5
# https://www.nytimes.com/2019/01/05/sports/hopman-cup-mens-team-tennis.html
# New file writing 6
# https://www.nytimes.com/2019/03/04/sports/tennis/dan-evans.html
# New file writing 7
# https://www.nytimes.com/reuters/2019/04/10/sports/tennis/10reuters-tennis-moore.html
# New file writing 8
# https://www.nytimes.com/2019/01/26/sports/tennis/naomi-osaka-australian-open.html
# New file writing 9
# https://www.nytimes.com/reuters/2019/04/06/sports/tennis/06reuters-tennis-charleston.html
# New file writing 10
# https://www.nytimes.com/2019/03/13/sports/naomi-osaka-indian-wells-tennis.html
# New file writing 11
# https://www.nytimes.com/reuters/2019/04/13/sports/tennis/13reuters-tennis-houston.html
# New file writing 12
# https://www.nytimes.com/reuters/2019/04/09/sports/tennis/09reuters-tennis-houston.html
# New file writing 13
# https://www.nytimes.com/reuters/2019/04/09/sports/tennis/08reuters-tennis-houston.html
# New file writing 14
# https://www.nytimes.com/2019/01/16/sports/tennis/australian-open-mauresmo-pouille.html
# New file writing 15
# https://www.nytimes.com/reuters/2019/04/14/sports/tennis/14reuters-tennis-houston.html
# New file writing 78
# https://www.nytimes.com/aponline/2019/04/17/sports/tennis/ap-ten-monte-carlo-masters.html
# New file writing 79
# https://www.nytimes.com/aponline/2019/04/14/sports/tennis/ap-ten-monte-carlo-masters.html
# New file writing 80
# https://www.nytimes.com/reuters/2019/04/14/sports/tennis/14reuters-tennis-lugano.html
# New file writing 81
# https://www.nytimes.com/reuters/2019/04/12/sports/tennis/12reuters-tennis-roundup.html
# New file writing 82
# https://www.nytimes.com/2019/01/10/sports/australian-open-draw.html
# New file writing 83
# https://www.nytimes.com/reuters/2019/04/13/sports/tennis/13reuters-tennis-roundup.html
# New file writing 84
# https://www.nytimes.com/reuters/2019/04/10/sports/tennis/10reuters-tennis-houston.html
# New file writing 85
# https://www.nytimes.com/reuters/2019/04/14/sports/tennis/14reuters-tennis-tennis-roundup.html
# New file writing 86
# https://www.nytimes.com/reuters/2019/04/14/sports/tennis/14reuters-tennis-marrakech.html
# New file writing 87
# https://www.nytimes.com/aponline/2019/04/14/sports/tennis/ap-ten-samsung-open.html
# New file writing 88
# https://www.nytimes.com/aponline/2019/04/10/sports/tennis/ap-ten-samsung-open.html
# New file writing 89
# https://www.nytimes.com/aponline/2019/04/11/sports/tennis/ap-ten-us-mens-clay-court.html
# New file writing 90
# https://www.nytimes.com/aponline/2019/04/13/sports/tennis/ap-ten-us-mens-clay-court-.html
# New file writing 91
# https://www.nytimes.com/reuters/2019/04/10/sports/tennis/10reuters-tennis-roundup.html
# New file writing 92
# https://www.nytimes.com/aponline/2019/04/13/sports/tennis/ap-ten-samsung-open.html
# New file writing 93
# https://www.nytimes.com/aponline/2019/04/09/sports/tennis/ap-ten-fed-cup-france.html
# New file writing 94
# https://www.nytimes.com/reuters/2019/04/11/sports/tennis/11reuters-tennis-tennis-roundup.html
# New file writing 95
# https://www.nytimes.com/reuters/2019/04/07/sports/tennis/07reuters-tennis-monterrey.html
# New file writing 96
# https://www.nytimes.com/reuters/2019/04/07/sports/tennis/07reuters-tennis-monterrey.html
# New file writing 97
# https://www.nytimes.com/reuters/2019/04/07/sports/tennis/07reuters-tennis-charleston.html
# New file writing 98
# https://www.nytimes.com/aponline/2019/04/10/sports/tennis/ap-ten-fed-cup-us.html
# New file writing 99
# https://www.nytimes.com/aponline/2019/04/09/sports/tennis/ap-ten-samsung-open.html
# New file writing 100
# https://www.nytimes.com/aponline/2019/04/09/sports/tennis/ap-ten-charleston.html
# New file writing 101
# https://www.nytimes.com/reuters/2019/04/06/sports/tennis/06reuters-tennis-tennis-roundup.html
# New file writing 102
# https://www.nytimes.com/2019/01/15/sports/tennis/golf-tiptoed-into-the-middle-east-then-dived-in.html
# New file writing 103
# https://www.nytimes.com/2019/01/14/briefing/china-brexit-australian-open.html
# New file writing 104
# https://www.nytimes.com/2019/01/22/briefing/kamala-harris-academy-award-nominations-australian-open.html
# New file writing 105
# https://www.nytimes.com/2019/01/17/briefing/shutdown-australian-open-john-bogle.html
# New file writing 106
# https://www.nytimes.com/2019/01/14/briefing/los-angeles-lion-air-australian-open.html
# New file writing 107
